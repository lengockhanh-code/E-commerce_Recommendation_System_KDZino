# %% [markdown]
# # Popularity + Trending
#
# Không train model. Notebook này chỉ kiểm tra các baseline/snapshot đã tạo ở preprocessing.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path(r"D:\MerRec")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)

# %% [markdown]
# ## Kiểm tra file

# %%
from training.utils.paths import (
    POPULARITY_TRAIN, TRENDING_TRAIN, SERVING_DIR
)

paths = [
    POPULARITY_TRAIN,
    TRENDING_TRAIN,
    SERVING_DIR / "popularity_snapshot.parquet",
    SERVING_DIR / "trending_snapshot.parquet",
]

for p in paths:
    print("✅" if p.exists() else "❌", p)

# %% [markdown]
# ## Xem Top Trending

# %%
import duckdb
from training.utils.paths import SERVING_DIR

p = SERVING_DIR / "trending_snapshot.parquet"
if p.exists():
    display(
        duckdb.sql(f"""
            SELECT *
            FROM read_parquet('{p.as_posix()}')
            ORDER BY trending_score DESC
            LIMIT 20
        """).df()
    )

# %% [markdown]
# # DCN
#
# GPU/Kaggle ranker. Dùng cùng candidate/features với DeepFM để so sánh công bằng.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path(r"D:\MerRec")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)

# %% [markdown]
# **Chạy Kaggle GPU.**

# %% [markdown]
# ## Cấu hình

# %%
RANK_EMBED_DIM = 16
RANK_EPOCHS = 8
RANK_BATCH_SIZE = 4096
RANK_LR = 1e-3

print("DCN: dùng cùng ranker dataset với DeepFM.")

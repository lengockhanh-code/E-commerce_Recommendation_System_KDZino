# %% [markdown]
# # LightGBM Ranker
#
# CPU ranker. Candidate dataset → numeric/categorical features → LambdaRank.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path(r"D:\MerRec")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)

# %% [markdown]
# ## Ghi chú

# %%
print(
    "LightGBM Ranker chạy CPU. "
    "Nên train sau khi ta tạo candidate dataset chung cho DeepFM/DCN/LightGBM."
)
